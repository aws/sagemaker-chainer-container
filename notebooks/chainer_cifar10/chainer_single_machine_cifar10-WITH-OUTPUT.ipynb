# %% [markdown]
# ## Training with Chainer
#
# [VGG](https://arxiv.org/pdf/1409.1556v6.pdf) is an architecture for deep convolution networks. In this example, we train a convolutional network to perform image classification using the CIFAR-10 dataset. CIFAR-10 consists of 60000 32x32 colour images in 10 classes, with 6000 images per class. There are 50000 training images and 10000 test images. We'll train a model on SageMaker, deploy it to Amazon SageMaker, and then classify images using the deployed model.
#
# To train with a Chainer script, we construct a ```Chainer``` estimator using the [sagemaker-python-sdk](https://github.com/aws/sagemaker-python-sdk). We can pass in an `entry_point`, the name of a script that contains a couple of functions with certain signatures (`train` and `model_fn`). This script will be run on SageMaker in a container that invokes these functions to train and load Chainer models.
#
# For more on the Chainer container, please visit the sagemaker-chainer-containers repository:
# https://github.com/aws/sagemaker-chainer-containers

# %%
# Setup
from sagemaker import get_execution_role
import sagemaker

sagemaker_session = sagemaker.Session()

# This role retrieves the SageMaker-compatible role used by this Notebook Instance.
role = get_execution_role()

# %% [markdown]
# ## Downloading training and test data
#
# We use helper functions given by `chainer` to download and preprocess the CIFAR10 data.

# %%
import chainer

from chainer.datasets import get_cifar10

train, test = get_cifar10()
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# ## Uploading the data
#
# We save the preprocessed data to the local filesystem, and then use the `sagemaker.Session.upload_data` function to upload our datasets to an S3 location. The return value `inputs` identifies the S3 location, which we will use when we start the Training Job.

# %%
import os
import shutil

import numpy as np

train_data = [element[0] for element in train]
train_labels = [element[1] for element in train]

test_data = [element[0] for element in test]
test_labels = [element[1] for element in test]

try:
    os.makedirs('data/train')
    os.makedirs('data/test')
except FileExistsError:
    pass

np.savez('data/train/train.npz', data=train_data, labels=train_labels)
np.savez('data/test/test.npz', data=test_data, labels=test_labels)

# Upload preprocessed data to S3 
train_input = sagemaker_session.upload_data(path=os.path.join('data', 'train'),
                                                            key_prefix='notebook/chainer_cifar/train')
test_input = sagemaker_session.upload_data(path=os.path.join('data', 'test'),
                                                           key_prefix='notebook/chainer_cifar/test')

# Remove data from notebook instance (to conserve disk space)
shutil.rmtree('data')

# %% [markdown]
# ## Writing the Chainer training script to run on Amazon SageMaker
#
# We need to provide a training script that can run on the SageMaker platform. The training scripts are essentially the same as one you would write for local training, except that you need to provide a function `train` that returns a trained model.
#
# Since we will use the same script to host the Chainer model, the script also needs a function `model_fn` that loads the model -- by default, Chainer models are saved to disk as `model.npz`. When SageMaker calls your `train` and `model_fn` functions, it will pass in arguments that describe the training environment.
#
# See the script below, which uses `chainer` to train on any number of GPUs on a single machine, to see how this works. For more on implementing these functions, see the documentation at https://github.com/aws/sagemaker-python-sdk.

# %%
# !cat 'code/chainer_cifar_vgg_single_machine.py'
# Out:
# # Copyright 2018 Amazon.com, Inc. or its affiliates. All Rights Reserved.
# #
# # Licensed under the Apache License, Version 2.0 (the "License"). You
# # may not use this file except in compliance with the License. A copy of
# # the License is located at
# #
# #     http://aws.amazon.com/apache2.0/
# #
# # or in the "license" file accompanying this file. This file is
# # distributed on an "AS IS" BASIS, WITHOUT WARRANTIES OR CONDITIONS OF
# # ANY KIND, either express or implied. See the License for the specific
# # language governing permissions and limitations under the License.
#
# from __future__ import print_function, absolute_import
#
# import os
#
# import numpy as np
#
# import chainer
# import chainer.functions as F
# import chainer.links as L
# from chainer import training
# from chainer import serializers
# from chainer.training import extensions
#
# import net
#
#
# def train(hyperparameters, num_gpus, output_data_dir, channel_input_dirs):
#     """
#     This function is called by the Chainer container during training when running on SageMaker with
#     values populated by the training environment.
#
#     Args:
#         hyperparameters (dict): map of hyperparameters given to the training job.
#         num_gpus (int): number of gpus available to the container, determined by instance type.
#         output_data_dir (str): path to the directory to write output artifacts to
#         channel_input_dirs (dict): Dictionary mapping input channel names to local filesystem paths
#
#     Returns:
#         a trained Chainer model
#
#     For more on `train`, please visit the sagemaker-python-sdk repository:
#     https://github.com/aws/sagemaker-python-sdk
#
#     For more on the Chainer container, please visit the sagemaker-chainer-containers repository:
#     https://github.com/aws/sagemaker-chainer-containers
#     """
#
#     train_data = np.load(os.path.join(channel_input_dirs['train'], 'train.npz'))['data']
#     train_labels = np.load(os.path.join(channel_input_dirs['train'], 'train.npz'))['labels']
#
#     test_data = np.load(os.path.join(channel_input_dirs['test'], 'test.npz'))['data']
#     test_labels = np.load(os.path.join(channel_input_dirs['test'], 'test.npz'))['labels']
#
#     train = chainer.datasets.TupleDataset(train_data, train_labels)
#     test = chainer.datasets.TupleDataset(test_data, test_labels)
#
#     # retrieve the hyperparameters we set in notebook (with some defaults)
#     batch_size = hyperparameters.get('batch_size', 64)
#     epochs = hyperparameters.get('epochs', 300)
#     learning_rate = hyperparameters.get('learning_rate', 0.05)
#     num_loaders = hyperparameters.get('num_loaders', None) # defaults to num_cpus
#
#     print('# Minibatch-size: {}'.format(batch_size))
#     print('# epoch: {}'.format(epochs))
#
#     # Set up a neural network to train.
#     # Classifier reports softmax cross entropy loss and accuracy at every
#     # iteration, which will be used by the PrintReport extension below.
#     model = L.Classifier(net.VGG(10))
#
#     optimizer = chainer.optimizers.MomentumSGD(learning_rate)
#     optimizer.setup(model)
#     optimizer.add_hook(chainer.optimizer.WeightDecay(5e-4))
#
#     # Set up a trainer
#     device = 0 if num_gpus > 0 else -1  # -1 indicates CPU, 0 indicates first GPU device.
#     if num_gpus > 1:
#         devices = range(num_gpus)
#         train_iters = [chainer.iterators.MultiprocessIterator(i, batch_size, n_processes=num_gpus) \
#                     for i in chainer.datasets.split_dataset_n_random(train, len(devices))]
#         test_iter = chainer.iterators.MultiprocessIterator(test, batch_size, repeat=False, n_processes=num_gpus)
#         updater = training.updaters.MultiprocessParallelUpdater(train_iters, optimizer, devices=range(num_gpus))
#     else:
#         train_iter = chainer.iterators.MultiprocessIterator(train, batch_size)
#         test_iter = chainer.iterators.MultiprocessIterator(test, batch_size, repeat=False)
#         updater = training.updater.StandardUpdater(train_iter, optimizer, device=device)
#
#     stop_trigger = (epochs, 'epoch')
#     trainer = training.Trainer(updater, stop_trigger, out=output_data_dir)
#     # Evaluate the model with the test dataset for each epoch
#     trainer.extend(extensions.Evaluator(test_iter, model, device=device))
#
#     # Reduce the learning rate by half every 25 epochs.
#     trainer.extend(extensions.ExponentialShift('lr', 0.5), trigger=(25, 'epoch'))
#
#     # Dump a computational graph from 'loss' variable at the first iteration
#     # The "main" refers to the target link of the "main" optimizer.
#     trainer.extend(extensions.dump_graph('main/loss'))
#
#     # Write a log of evaluation statistics for each epoch
#     trainer.extend(extensions.LogReport())
#
#     if extensions.PlotReport.available():
#         trainer.extend(
#             extensions.PlotReport(['main/loss', 'validation/main/loss'],
#                                   'epoch', file_name='loss.png'))
#         trainer.extend(
#             extensions.PlotReport(
#                 ['main/accuracy', 'validation/main/accuracy'],
#                 'epoch', file_name='accuracy.png'))
#
#     # Print selected entries of the log to stdout
#     # Here "main" refers to the target link of the "main" optimizer again, and
#     # "validation" refers to the default name of the Evaluator extension.
#     # Entries other than 'epoch' are reported by the Classifier link, called by
#     # either the updater or the evaluator.
#     trainer.extend(extensions.PrintReport(
#         ['epoch', 'main/loss', 'validation/main/loss',
#          'main/accuracy', 'validation/main/accuracy', 'elapsed_time']))
#
#     # Print a progress bar to stdout
#     trainer.extend(extensions.ProgressBar())
#
#     # Run the training
#
#     trainer.run()
#
#     return model
#
#
# def model_fn(model_dir):
#     """
#     This function is called by the Chainer container during hosting when running on SageMaker with
#     values populated by the hosting environment.
#
#     By default, the Chainer container saves models as .npz files, with the name 'model.npz'. In
#     your training script, you can override this behavior by implementing a function with
#     signature `save(model, model_dir)`.
#
#     Args:
#         model_dir (str): path to the directory containing the saved model artifacts
#
#     Returns:
#         a loaded Chainer model
#
#     For more on `model_fn` and `save`, please visit the sagemaker-python-sdk repository:
#     https://github.com/aws/sagemaker-python-sdk
#
#     For more on the Chainer container, please visit the sagemaker-chainer-containers repository:
#     https://github.com/aws/sagemaker-chainer-containers
#     """
#     chainer.config.train = False
#     model = L.Classifier(net.VGG(10))
#     serializers.load_npz(os.path.join(model_dir, 'model.npz'), model)
#     return model.predictor

# %% [markdown]
# ## Running the training script on SageMaker
#
# The ```Chainer``` class allows us to run our training function as a training job on SageMaker infrastructure. We need to configure it with our training script, an IAM role, the number of training instances, and the training instance type. In this case we will run our training job on two `ml.p3.2xlarge` instances.
#
# This script uses the `chainermn` package, which distributes training with MPI. Your script is run with `mpirun`, so a `chainermn
#
# Chainer scripts can distribute training with the `chainermn` package, which this Chainer script does not use, so this script should only be run on one instance.

# %%
from sagemaker.chainer.estimator import Chainer

chainer_estimator = Chainer(entry_point='chainer_cifar_vgg_single_machine.py', source_dir="code", role=role,
                            sagemaker_session=sagemaker_session,
                            train_instance_count=1, train_instance_type='ml.p3.2xlarge',
                            hyperparameters={'epochs': 50, 'batch_size': 64})

chainer_estimator.fit({'train': train_input, 'test': test_input})
# Out:
# INFO:sagemaker:Creating training-job with name: sagemaker-chainer-2018-05-04-20-05-57-636
# ...................................................
# 2018-05-04 20:10:03,802 INFO - root - running container entrypoint
# 2018-05-04 20:10:03,802 INFO - root - starting train task
# 2018-05-04 20:10:03,814 INFO - container_support.app - started training: {'train_fn': <function train at 0x7f95f865abf8>}
# Downloading s3://sagemaker-us-west-2-038453126632/sagemaker-chainer-2018-05-04-20-05-57-636/source/sourcedir.tar.gz to /tmp/script.tar.gz
# 2018-05-04 20:10:03,970 INFO - botocore.vendored.requests.packages.urllib3.connectionpool - Starting new HTTP connection (1): 169.254.170.2
# 2018-05-04 20:10:04,055 INFO - botocore.vendored.requests.packages.urllib3.connectionpool - Starting new HTTPS connection (1): sagemaker-us-west-2-038453126632.s3.amazonaws.com
# 2018-05-04 20:10:04,091 INFO - botocore.vendored.requests.packages.urllib3.connectionpool - Starting new HTTPS connection (2): sagemaker-us-west-2-038453126632.s3.amazonaws.com
# 2018-05-04 20:10:04,104 INFO - botocore.vendored.requests.packages.urllib3.connectionpool - Starting new HTTPS connection (1): sagemaker-us-west-2-038453126632.s3.us-west-2.amazonaws.com
# 2018-05-04 20:10:04,155 INFO - botocore.vendored.requests.packages.urllib3.connectionpool - Starting new HTTPS connection (2): sagemaker-us-west-2-038453126632.s3.us-west-2.amazonaws.com
# 2018-05-04 20:10:04,305 INFO - chainer_framework.training - Invoking user training script.
# # Minibatch-size: 64
# # epoch: 50
# 2018-05-04 20:10:20,768 INFO - matplotlib.font_manager - font search path ['/usr/local/lib/python3.5/dist-packages/matplotlib/mpl-data/fonts/ttf', '/usr/local/lib/python3.5/dist-packages/matplotlib/mpl-data/fonts/afm', '/usr/local/lib/python3.5/dist-packages/matplotlib/mpl-data/fonts/pdfcorefonts']
# 2018-05-04 20:10:21,157 INFO - matplotlib.font_manager - generated new fontManager
# epoch       main/loss   validation/main/loss  main/accuracy  validation/main/accuracy  elapsed_time
# #033[J     total [..................................................]  0.26%
# this epoch [######............................................] 12.80%
#        100 iter, 0 epoch / 50 epochs
#        inf iters/sec. Estimated time to finish: 0:00:00.
# #033[4A#033[J     total [..................................................]  0.51%
# this epoch [############......................................] 25.60%
#        200 iter, 0 epoch / 50 epochs
#     28.279 iters/sec. Estimated time to finish: 0:22:54.246014.
# #033[4A#033[J     total [..................................................]  0.77%
# this epoch [###################...............................] 38.40%
#        300 iter, 0 epoch / 50 epochs
#     28.381 iters/sec. Estimated time to finish: 0:22:45.777821.
# #033[4A#033[J     total [..................................................]  1.02%
# this epoch [#########################.........................] 51.20%
#        400 iter, 0 epoch / 50 epochs
#      28.37 iters/sec. Estimated time to finish: 0:22:42.818994.
# #033[4A#033[J     total [..................................................]  1.28%
# this epoch [################################..................] 64.00%
#        500 iter, 0 epoch / 50 epochs
#     28.376 iters/sec. Estimated time to finish: 0:22:38.986857.
# #033[4A#033[J     total [..................................................]  1.54%
# this epoch [######################################............] 76.80%
#        600 iter, 0 epoch / 50 epochs
#     28.382 iters/sec. Estimated time to finish: 0:22:35.165908.
# #033[4A#033[J     total [..................................................]  1.79%
# this epoch [############################################......] 89.60%
#        700 iter, 0 epoch / 50 epochs
#      28.39 iters/sec. Estimated time to finish: 0:22:31.244367.
# #033[4A#033[J1           2.29963     1.88504               0.186461       0.250796                  45.8527
# #033[J     total [#.................................................]  2.05%
# this epoch [#.................................................]  2.40%
#        800 iter, 1 epoch / 50 epochs
#     25.247 iters/sec. Estimated time to finish: 0:25:15.498363.
# #033[4A#033[J     total [#.................................................]  2.30%
# this epoch [#######...........................................] 15.20%
#        900 iter, 1 epoch / 50 epochs
#      25.59 iters/sec. Estimated time to finish: 0:24:51.284100.
# #033[4A#033[J     total [#.................................................]  2.56%
# this epoch [##############....................................] 28.00%
#       1000 iter, 1 epoch / 50 epochs
#     25.866 iters/sec. Estimated time to finish: 0:24:31.512490.
# #033[4A#033[J     total [#.................................................]  2.82%
# this epoch [####################..............................] 40.80%
#       1100 iter, 1 epoch / 50 epochs
#     26.079 iters/sec. Estimated time to finish: 0:24:15.683604.
# #033[4A#033[J     total [#.................................................]  3.07%
# this epoch [##########################........................] 53.60%
#       1200 iter, 1 epoch / 50 epochs
#     26.269 iters/sec. Estimated time to finish: 0:24:01.323766.
# #033[4A#033[J     total [#.................................................]  3.33%
# this epoch [#################################.................] 66.40%
#       1300 iter, 1 epoch / 50 epochs
#      26.43 iters/sec. Estimated time to finish: 0:23:48.774249.
# #033[4A#033[J     total [#.................................................]  3.58%
# this epoch [#######################################...........] 79.20%
#       1400 iter, 1 epoch / 50 epochs
#     26.562 iters/sec. Estimated time to finish: 0:23:37.926385.
# #033[4A#033[J     total [#.................................................]  3.84%
# this epoch [##############################################....] 92.00%
#       1500 iter, 1 epoch / 50 epochs
#     26.676 iters/sec. Estimated time to finish: 0:23:28.111734.
# #033[4A#033[J2           1.71098     1.55863               0.329525       0.404857                  76.0753
# #033[J     total [##................................................]  4.10%
# this epoch [##................................................]  4.80%
#       1600 iter, 2 epoch / 50 epochs
#      25.58 iters/sec. Estimated time to finish: 0:24:24.512066.
# #033[4A#033[J     total [##................................................]  4.35%
# this epoch [########..........................................] 17.60%
#       1700 iter, 2 epoch / 50 epochs
#     25.741 iters/sec. Estimated time to finish: 0:24:11.451798.
# #033[4A#033[J     total [##................................................]  4.61%
# this epoch [###############...................................] 30.40%
#       1800 iter, 2 epoch / 50 epochs
#     25.882 iters/sec. Estimated time to finish: 0:23:59.734138.
# #033[4A#033[J     total [##................................................]  4.86%
# this epoch [#####################.............................] 43.20%
#       1900 iter, 2 epoch / 50 epochs
#     26.011 iters/sec. Estimated time to finish: 0:23:48.731391.
# #033[4A#033[J     total [##................................................]  5.12%
# this epoch [############################......................] 56.00%
#       2000 iter, 2 epoch / 50 epochs
#     26.124 iters/sec. Estimated time to finish: 0:23:38.736787.
# #033[4A#033[J     total [##................................................]  5.38%
# this epoch [##################################................] 68.80%
#       2100 iter, 2 epoch / 50 epochs
#     26.226 iters/sec. Estimated time to finish: 0:23:29.393352.
# #033[4A#033[J     total [##................................................]  5.63%
# this epoch [########################################..........] 81.60%
#       2200 iter, 2 epoch / 50 epochs
#     26.319 iters/sec. Estimated time to finish: 0:23:20.620494.
# #033[4A#033[J     total [##................................................]  5.89%
# this epoch [###############################################...] 94.40%
#       2300 iter, 2 epoch / 50 epochs
#     26.406 iters/sec. Estimated time to finish: 0:23:12.182037.
# #033[4A#033[J3           1.45249     1.33205               0.456486       0.517815                  106.216
# #033[J     total [###...............................................]  6.14%
# this epoch [###...............................................]  7.20%
#       2400 iter, 3 epoch / 50 epochs
#      25.72 iters/sec. Estimated time to finish: 0:23:45.462532.
# #033[4A#033[J     total [###...............................................]  6.40%
# this epoch [##########........................................] 20.00%
#       2500 iter, 3 epoch / 50 epochs
#     25.806 iters/sec. Estimated time to finish: 0:23:36.829590.
# #033[4A#033[J     total [###...............................................]  6.66%
# this epoch [################..................................] 32.80%
#       2600 iter, 3 epoch / 50 epochs
#       25.9 iters/sec. Estimated time to finish: 0:23:27.815329.
# #033[4A#033[J     total [###...............................................]  6.91%
# this epoch [######################............................] 45.60%
#       2700 iter, 3 epoch / 50 epochs
#     25.979 iters/sec. Estimated time to finish: 0:23:19.667481.
# #033[4A#033[J     total [###...............................................]  7.17%
# this epoch [#############################.....................] 58.40%
#       2800 iter, 3 epoch / 50 epochs
#     26.056 iters/sec. Estimated time to finish: 0:23:11.722373.
# #033[4A#033[J     total [###...............................................]  7.42%
# this epoch [###################################...............] 71.20%
#       2900 iter, 3 epoch / 50 epochs
#     26.131 iters/sec. Estimated time to finish: 0:23:03.876356.
# #033[4A#033[J     total [###...............................................]  7.68%
# this epoch [#########################################.........] 84.00%
#       3000 iter, 3 epoch / 50 epochs
#     26.201 iters/sec. Estimated time to finish: 0:22:56.369099.
# #033[4A#033[J     total [###...............................................]  7.94%
# this epoch [################################################..] 96.80%
#       3100 iter, 3 epoch / 50 epochs
#     26.266 iters/sec. Estimated time to finish: 0:22:49.173778.
# #033[4A#033[J4           1.20956     1.26386               0.573323       0.540207                  136.447
# #033[J     total [####..............................................]  8.19%
# this epoch [####..............................................]  9.60%
#       3200 iter, 4 epoch / 50 epochs
#     25.764 iters/sec. Estimated time to finish: 0:23:11.984719.
# #033[4A#033[J     total [####..............................................]  8.45%
# this epoch [###########.......................................] 22.40%
#       3300 iter, 4 epoch / 50 epochs
#     25.833 iters/sec. Estimated time to finish: 0:23:04.348589.
# #033[4A#033[J     total [####..............................................]  8.70%
# this epoch [#################.................................] 35.20%
#       3400 iter, 4 epoch / 50 epochs
#     25.902 iters/sec. Estimated time to finish: 0:22:56.818103.
# #033[4A#033[J     total [####..............................................]  8.96%
# this epoch [########################..........................] 48.00%
#       3500 iter, 4 epoch / 50 epochs
#     25.966 iters/sec. Estimated time to finish: 0:22:49.593099.
# #033[4A#033[J     total [####..............................................]  9.22%
# this epoch [##############################....................] 60.80%
#       3600 iter, 4 epoch / 50 epochs
#     26.029 iters/sec. Estimated time to finish: 0:22:42.426125.
# #033[4A#033[J     total [####..............................................]  9.47%
# this epoch [####################################..............] 73.60%
#       3700 iter, 4 epoch / 50 epochs
#     26.088 iters/sec. Estimated time to finish: 0:22:35.534202.
# #033[4A#033[J     total [####..............................................]  9.73%
# this epoch [###########################################.......] 86.40%
#       3800 iter, 4 epoch / 50 epochs
#     26.143 iters/sec. Estimated time to finish: 0:22:28.855873.
# #033[4A#033[J     total [####..............................................]  9.98%
# this epoch [#################################################.] 99.20%
#       3900 iter, 4 epoch / 50 epochs
#     26.194 iters/sec. Estimated time to finish: 0:22:22.395340.
# #033[4A#033[J5           1.04974     1.44735               0.637428       0.525478                  166.661
# #033[J     total [#####.............................................] 10.24%
# this epoch [######............................................] 12.00%
#       4000 iter, 5 epoch / 50 epochs
#     25.794 iters/sec. Estimated time to finish: 0:22:39.330235.
# #033[4A#033[J     total [#####.............................................] 10.50%
# this epoch [############......................................] 24.80%
#       4100 iter, 5 epoch / 50 epochs
#      25.85 iters/sec. Estimated time to finish: 0:22:32.493514.
# #033[4A#033[J     total [#####.............................................] 10.75%
# this epoch [##################................................] 37.60%
#       4200 iter, 5 epoch / 50 epochs
#     25.902 iters/sec. Estimated time to finish: 0:22:25.956793.
# #033[4A#033[J     total [#####.............................................] 11.01%
# this epoch [#########################.........................] 50.40%
#       4300 iter, 5 epoch / 50 epochs
#     25.952 iters/sec. Estimated time to finish: 0:22:19.505545.
# #033[4A#033[J     total [#####.............................................] 11.26%
# this epoch [###############################...................] 63.20%
#       4400 iter, 5 epoch / 50 epochs
#     26.002 iters/sec. Estimated time to finish: 0:22:13.063988.
# #033[4A#033[J     total [#####.............................................] 11.52%
# this epoch [#####################################.............] 76.00%
#       4500 iter, 5 epoch / 50 epochs
#     26.049 iters/sec. Estimated time to finish: 0:22:06.800965.
# #033[4A#033[J     total [#####.............................................] 11.78%
# this epoch [############################################......] 88.80%
#       4600 iter, 5 epoch / 50 epochs
#     26.097 iters/sec. Estimated time to finish: 0:22:00.552283.
# #033[4A#033[J6           0.945999    0.889275              0.677277       0.69377                   196.868
# #033[J     total [######............................................] 12.03%
# this epoch [..................................................]  1.60%
#       4700 iter, 6 epoch / 50 epochs
#     25.771 iters/sec. Estimated time to finish: 0:22:13.396768.
# #033[4A#033[J     total [######............................................] 12.29%
# this epoch [#######...........................................] 14.40%
#       4800 iter, 6 epoch / 50 epochs
#     25.819 iters/sec. Estimated time to finish: 0:22:07.046698.
# #033[4A#033[J     total [######............................................] 12.54%
# this epoch [#############.....................................] 27.20%
#       4900 iter, 6 epoch / 50 epochs
#     25.864 iters/sec. Estimated time to finish: 0:22:00.836345.
# #033[4A#033[J     total [######............................................] 12.80%
# this epoch [####################..............................] 40.00%
#       5000 iter, 6 epoch / 50 epochs
#     25.912 iters/sec. Estimated time to finish: 0:21:54.549064.
# #033[4A#033[J     total [######............................................] 13.06%
# this epoch [##########################........................] 52.80%
#       5100 iter, 6 epoch / 50 epochs
#     25.956 iters/sec. Estimated time to finish: 0:21:48.458398.
# #033[4A#033[J     total [######............................................] 13.31%
# this epoch [################################..................] 65.60%
#       5200 iter, 6 epoch / 50 epochs
#     25.997 iters/sec. Estimated time to finish: 0:21:42.551724.
# #033[4A#033[J     total [######............................................] 13.57%
# this epoch [#######################################...........] 78.40%
#       5300 iter, 6 epoch / 50 epochs
#     26.036 iters/sec. Estimated time to finish: 0:21:36.751916.
# #033[4A#033[J     total [######............................................] 13.82%
# this epoch [#############################################.....] 91.20%
#       5400 iter, 6 epoch / 50 epochs
#     26.075 iters/sec. Estimated time to finish: 0:21:30.987540.
# #033[4A#033[J7           0.881214    0.845455              0.705466       0.720541                  227.037
# #033[J     total [#######...........................................] 14.08%
# this epoch [##................................................]  4.00%
#       5500 iter, 7 epoch / 50 epochs
#     25.793 iters/sec. Estimated time to finish: 0:21:41.234377.
# #033[4A#033[J     total [#######...........................................] 14.34%
# this epoch [########..........................................] 16.80%
#       5600 iter, 7 epoch / 50 epochs
#     25.834 iters/sec. Estimated time to finish: 0:21:35.287713.
# #033[4A#033[J     total [#######...........................................] 14.59%
# this epoch [##############....................................] 29.60%
#       5700 iter, 7 epoch / 50 epochs
#     25.874 iters/sec. Estimated time to finish: 0:21:29.415381.
# #033[4A#033[J     total [#######...........................................] 14.85%
# this epoch [#####################.............................] 42.40%
#       5800 iter, 7 epoch / 50 epochs
#     25.913 iters/sec. Estimated time to finish: 0:21:23.604471.
# #033[4A#033[J     total [#######...........................................] 15.10%
# this epoch [###########################.......................] 55.20%
#       5900 iter, 7 epoch / 50 epochs
#     25.952 iters/sec. Estimated time to finish: 0:21:17.847304.
# #033[4A#033[J     total [#######...........................................] 15.36%
# this epoch [#################################.................] 68.00%
#       6000 iter, 7 epoch / 50 epochs
#     25.988 iters/sec. Estimated time to finish: 0:21:12.217579.
# #033[4A#033[J     total [#######...........................................] 15.62%
# this epoch [########################################..........] 80.80%
#       6100 iter, 7 epoch / 50 epochs
#     26.025 iters/sec. Estimated time to finish: 0:21:06.579917.
# #033[4A#033[J     total [#######...........................................] 15.87%
# this epoch [##############################################....] 93.60%
#       6200 iter, 7 epoch / 50 epochs
#      26.06 iters/sec. Estimated time to finish: 0:21:01.034675.
# #033[4A#033[J8           0.821788    0.869772              0.731514       0.709196                  257.157
# #033[J     total [########..........................................] 16.13%
# this epoch [###...............................................]  6.40%
#       6300 iter, 8 epoch / 50 epochs
#     25.818 iters/sec. Estimated time to finish: 0:21:08.983235.
# #033[4A#033[J     total [########..........................................] 16.38%
# this epoch [#########.........................................] 19.20%
#       6400 iter, 8 epoch / 50 epochs
#     25.856 iters/sec. Estimated time to finish: 0:21:03.268265.
# #033[4A#033[J     total [########..........................................] 16.64%
# this epoch [################..................................] 32.00%
#       6500 iter, 8 epoch / 50 epochs
#     25.893 iters/sec. Estimated time to finish: 0:20:57.588718.
# #033[4A#033[J     total [########..........................................] 16.90%
# this epoch [######################............................] 44.80%
#       6600 iter, 8 epoch / 50 epochs
#     25.928 iters/sec. Estimated time to finish: 0:20:52.040398.
# #033[4A#033[J     total [########..........................................] 17.15%
# this epoch [############################......................] 57.60%
#       6700 iter, 8 epoch / 50 epochs
#     25.961 iters/sec. Estimated time to finish: 0:20:46.594384.
# #033[4A#033[J     total [########..........................................] 17.41%
# this epoch [###################################...............] 70.40%
#       6800 iter, 8 epoch / 50 epochs
#     25.994 iters/sec. Estimated time to finish: 0:20:41.171602.
# #033[4A#033[J     total [########..........................................] 17.66%
# this epoch [#########################################.........] 83.20%
#       6900 iter, 8 epoch / 50 epochs
#     26.027 iters/sec. Estimated time to finish: 0:20:35.755466.
# #033[4A#033[J     total [########..........................................] 17.92%
# this epoch [################################################..] 96.00%
#       7000 iter, 8 epoch / 50 epochs
#     26.058 iters/sec. Estimated time to finish: 0:20:30.439183.
# #033[4A#033[J9           0.775107    0.818701              0.75004        0.736664                  287.265
# #033[J     total [#########.........................................] 18.18%
# this epoch [####..............................................]  8.80%
#       7100 iter, 9 epoch / 50 epochs
#      25.84 iters/sec. Estimated time to finish: 0:20:36.949963.
# #033[4A#033[J     total [#########.........................................] 18.43%
# this epoch [##########........................................] 21.60%
#       7200 iter, 9 epoch / 50 epochs
#     25.873 iters/sec. Estimated time to finish: 0:20:31.498538.
# #033[4A#033[J     total [#########.........................................] 18.69%
# this epoch [#################.................................] 34.40%
#       7300 iter, 9 epoch / 50 epochs
#     25.902 iters/sec. Estimated time to finish: 0:20:26.249298.
# #033[4A#033[J     total [#########.........................................] 18.94%
# this epoch [#######################...........................] 47.20%
#       7400 iter, 9 epoch / 50 epochs
#     25.931 iters/sec. Estimated time to finish: 0:20:21.049873.
# #033[4A#033[J     total [#########.........................................] 19.20%
# this epoch [#############################.....................] 60.00%
#       7500 iter, 9 epoch / 50 epochs
#     25.958 iters/sec. Estimated time to finish: 0:20:15.913343.
# #033[4A#033[J     total [#########.........................................] 19.46%
# this epoch [####################################..............] 72.80%
#       7600 iter, 9 epoch / 50 epochs
#     25.986 iters/sec. Estimated time to finish: 0:20:10.757838.
# #033[4A#033[J     total [#########.........................................] 19.71%
# this epoch [##########################################........] 85.60%
#       7700 iter, 9 epoch / 50 epochs
#     26.013 iters/sec. Estimated time to finish: 0:20:05.639002.
# #033[4A#033[J     total [#########.........................................] 19.97%
# this epoch [#################################################.] 98.40%
#       7800 iter, 9 epoch / 50 epochs
#     26.041 iters/sec. Estimated time to finish: 0:20:00.512723.
# #033[4A#033[J10          0.746963    1.0989                0.758763       0.646397                  317.466
# #033[J     total [##########........................................] 20.22%
# this epoch [#####.............................................] 11.20%
#       7900 iter, 10 epoch / 50 epochs
#     25.849 iters/sec. Estimated time to finish: 0:20:05.573205.
# #033[4A#033[J     total [##########........................................] 20.48%
# this epoch [############......................................] 24.00%
#       8000 iter, 10 epoch / 50 epochs
#     25.877 iters/sec. Estimated time to finish: 0:20:00.368435.
# #033[4A#033[J     total [##########........................................] 20.74%
# this epoch [##################................................] 36.80%
#       8100 iter, 10 epoch / 50 epochs
#     25.905 iters/sec. Estimated time to finish: 0:19:55.221820.
# #033[4A#033[J     total [##########........................................] 20.99%
# this epoch [########################..........................] 49.60%
#       8200 iter, 10 epoch / 50 epochs
#     25.932 iters/sec. Estimated time to finish: 0:19:50.126355.
# #033[4A#033[J     total [##########........................................] 21.25%
# this epoch [###############################...................] 62.40%
#       8300 iter, 10 epoch / 50 epochs
#     25.958 iters/sec. Estimated time to finish: 0:19:45.097490.
# #033[4A#033[J     total [##########........................................] 21.50%
# this epoch [#####################################.............] 75.20%
#       8400 iter, 10 epoch / 50 epochs
#     25.985 iters/sec. Estimated time to finish: 0:19:40.029077.
# #033[4A#033[J     total [##########........................................] 21.76%
# this epoch [############################################......] 88.00%
#       8500 iter, 10 epoch / 50 epochs
#      26.01 iters/sec. Estimated time to finish: 0:19:35.030354.
# #033[4A#033[J11          0.720952    0.878712              0.767646       0.712182                  347.608
# #033[J     total [###########.......................................] 22.02%
# this epoch [..................................................]  0.80%
#       8600 iter, 11 epoch / 50 epochs
#     25.836 iters/sec. Estimated time to finish: 0:19:39.080662.
# #033[4A#033[J     total [###########.......................................] 22.27%
# this epoch [######............................................] 13.60%
#       8700 iter, 11 epoch / 50 epochs
#     25.861 iters/sec. Estimated time to finish: 0:19:34.047580.
# #033[4A#033[J     total [###########.......................................] 22.53%
# this epoch [#############.....................................] 26.40%
#       8800 iter, 11 epoch / 50 epochs
#     25.887 iters/sec. Estimated time to finish: 0:19:29.031333.
# #033[4A#033[J     total [###########.......................................] 22.78%
# this epoch [###################...............................] 39.20%
#       8900 iter, 11 epoch / 50 epochs
#      25.91 iters/sec. Estimated time to finish: 0:19:24.114923.
# #033[4A#033[J     total [###########.......................................] 23.04%
# this epoch [#########################.........................] 52.00%
#       9000 iter, 11 epoch / 50 epochs
#     25.932 iters/sec. Estimated time to finish: 0:19:19.279814.
# #033[4A#033[J     total [###########.......................................] 23.30%
# this epoch [################################..................] 64.80%
#       9100 iter, 11 epoch / 50 epochs
#     25.956 iters/sec. Estimated time to finish: 0:19:14.354287.
# #033[4A#033[J     total [###########.......................................] 23.55%
# this epoch [######################################............] 77.60%
#       9200 iter, 11 epoch / 50 epochs
#     25.981 iters/sec. Estimated time to finish: 0:19:09.385224.
# #033[4A#033[J     total [###########.......................................] 23.81%
# this epoch [#############################################.....] 90.40%
#       9300 iter, 11 epoch / 50 epochs
#     26.005 iters/sec. Estimated time to finish: 0:19:04.481938.
# #033[4A#033[J12          0.696561    0.748132              0.777209       0.762938                  377.758
# #033[J     total [############......................................] 24.06%
# this epoch [#.................................................]  3.20%
#       9400 iter, 12 epoch / 50 epochs
#     25.846 iters/sec. Estimated time to finish: 0:19:07.670784.
# #033[4A#033[J     total [############......................................] 24.32%
# this epoch [########..........................................] 16.00%
#       9500 iter, 12 epoch / 50 epochs
#     25.869 iters/sec. Estimated time to finish: 0:19:02.759666.
# #033[4A#033[J     total [############......................................] 24.58%
# this epoch [##############....................................] 28.80%
#       9600 iter, 12 epoch / 50 epochs
#     25.891 iters/sec. Estimated time to finish: 0:18:57.928072.
# #033[4A#033[J     total [############......................................] 24.83%
# this epoch [####################..............................] 41.60%
#       9700 iter, 12 epoch / 50 epochs
#     25.913 iters/sec. Estimated time to finish: 0:18:53.100859.
# #033[4A#033[J     total [############......................................] 25.09%
# this epoch [###########################.......................] 54.40%
#       9800 iter, 12 epoch / 50 epochs
#     25.936 iters/sec. Estimated time to finish: 0:18:48.243941.
# #033[4A#033[J     total [############......................................] 25.34%
# this epoch [#################################.................] 67.20%
#       9900 iter, 12 epoch / 50 epochs
#     25.959 iters/sec. Estimated time to finish: 0:18:43.421287.
# #033[4A#033[J     total [############......................................] 25.60%
# this epoch [########################################..........] 80.00%
#      10000 iter, 12 epoch / 50 epochs
#      25.98 iters/sec. Estimated time to finish: 0:18:38.652236.
# #033[4A#033[J     total [############......................................] 25.86%
# this epoch [##############################################....] 92.80%
#      10100 iter, 12 epoch / 50 epochs
#     26.002 iters/sec. Estimated time to finish: 0:18:33.874070.
# #033[4A#033[J13          0.676661    0.735564              0.782908       0.756768                  407.953
# #033[J     total [#############.....................................] 26.11%
# this epoch [##................................................]  5.60%
#      10200 iter, 13 epoch / 50 epochs
#      25.83 iters/sec. Estimated time to finish: 0:18:37.397204.
# #033[4A#033[J     total [#############.....................................] 26.37%
# this epoch [#########.........................................] 18.40%
#      10300 iter, 13 epoch / 50 epochs
#     25.828 iters/sec. Estimated time to finish: 0:18:33.610953.
# #033[4A#033[J     total [#############.....................................] 26.62%
# this epoch [###############...................................] 31.20%
#      10400 iter, 13 epoch / 50 epochs
#     25.824 iters/sec. Estimated time to finish: 0:18:29.923938.
# #033[4A#033[J     total [#############.....................................] 26.88%
# this epoch [#####################.............................] 44.00%
#      10500 iter, 13 epoch / 50 epochs
#     25.823 iters/sec. Estimated time to finish: 0:18:26.082368.
# #033[4A#033[J     total [#############.....................................] 27.14%
# this epoch [############################......................] 56.80%
#      10600 iter, 13 epoch / 50 epochs
#     25.822 iters/sec. Estimated time to finish: 0:18:22.239497.
# #033[4A#033[J     total [#############.....................................] 27.39%
# this epoch [##################################................] 69.60%
#      10700 iter, 13 epoch / 50 epochs
#     25.817 iters/sec. Estimated time to finish: 0:18:18.590499.
# #033[4A#033[J     total [#############.....................................] 27.65%
# this epoch [#########################################.........] 82.40%
#      10800 iter, 13 epoch / 50 epochs
#     26.011 iters/sec. Estimated time to finish: 0:18:06.541750.
# #033[4A#033[J     total [#############.....................................] 27.90%
# this epoch [###############################################...] 95.20%
#      10900 iter, 13 epoch / 50 epochs
#     26.009 iters/sec. Estimated time to finish: 0:18:02.802818.
# #033[4A#033[J14          0.663885    0.800065              0.786752       0.748109                  438.548
# #033[J     total [##############....................................] 28.16%
# this epoch [####..............................................]  8.00%
#      11000 iter, 14 epoch / 50 epochs
#      25.83 iters/sec. Estimated time to finish: 0:18:06.450834.
# #033[4A#033[J     total [##############....................................] 28.42%
# this epoch [##########........................................] 20.80%
#      11100 iter, 14 epoch / 50 epochs
#      25.83 iters/sec. Estimated time to finish: 0:18:02.554334.
# #033[4A#033[J     total [##############....................................] 28.67%
# this epoch [################..................................] 33.60%
#      11200 iter, 14 epoch / 50 epochs
#     25.829 iters/sec. Estimated time to finish: 0:17:58.729954.
# #033[4A#033[J     total [##############....................................] 28.93%
# this epoch [#######################...........................] 46.40%
#      11300 iter, 14 epoch / 50 epochs
#     25.827 iters/sec. Estimated time to finish: 0:17:54.934231.
# #033[4A#033[J     total [##############....................................] 29.18%
# this epoch [#############################.....................] 59.20%
#      11400 iter, 14 epoch / 50 epochs
#     25.827 iters/sec. Estimated time to finish: 0:17:51.072825.
# #033[4A#033[J     total [##############....................................] 29.44%
# this epoch [####################################..............] 72.00%
#      11500 iter, 14 epoch / 50 epochs
#     25.827 iters/sec. Estimated time to finish: 0:17:47.216324.
# #033[4A#033[J     total [##############....................................] 29.70%
# this epoch [##########################################........] 84.80%
#      11600 iter, 14 epoch / 50 epochs
#     26.003 iters/sec. Estimated time to finish: 0:17:36.127023.
# #033[4A#033[J     total [##############....................................] 29.95%
# this epoch [################################################..] 97.60%
#      11700 iter, 14 epoch / 50 epochs
#     26.003 iters/sec. Estimated time to finish: 0:17:32.278511.
# #033[4A#033[J15          0.656127    0.814326              0.791273       0.737759                  468.716
# #033[J     total [###############...................................] 30.21%
# this epoch [#####.............................................] 10.40%
#      11800 iter, 15 epoch / 50 epochs
#     25.832 iters/sec. Estimated time to finish: 0:17:35.383496.
# #033[4A#033[J     total [###############...................................] 30.46%
# this epoch [###########.......................................] 23.20%
#      11900 iter, 15 epoch / 50 epochs
#     25.832 iters/sec. Estimated time to finish: 0:17:31.501733.
# #033[4A#033[J     total [###############...................................] 30.72%
# this epoch [#################.................................] 36.00%
#      12000 iter, 15 epoch / 50 epochs
#     25.832 iters/sec. Estimated time to finish: 0:17:27.623036.
# #033[4A#033[J     total [###############...................................] 30.98%
# this epoch [########################..........................] 48.80%
#      12100 iter, 15 epoch / 50 epochs
#     25.833 iters/sec. Estimated time to finish: 0:17:23.705920.
# #033[4A#033[J     total [###############...................................] 31.23%
# this epoch [##############################....................] 61.60%
#      12200 iter, 15 epoch / 50 epochs
#     25.834 iters/sec. Estimated time to finish: 0:17:19.815701.
# #033[4A#033[J     total [###############...................................] 31.49%
# this epoch [#####################################.............] 74.40%
#      12300 iter, 15 epoch / 50 epochs
#     25.835 iters/sec. Estimated time to finish: 0:17:15.904004.
# #033[4A#033[J     total [###############...................................] 31.74%
# this epoch [###########################################.......] 87.20%
#      12400 iter, 15 epoch / 50 epochs
#      26.01 iters/sec. Estimated time to finish: 0:17:05.080501.
# #033[4A#033[J16          0.647076    0.767434              0.792774       0.740346                  498.707
# #033[J     total [################..................................] 32.00%
# this epoch [..................................................]  0.00%
#      12500 iter, 16 epoch / 50 epochs
#     25.846 iters/sec. Estimated time to finish: 0:17:07.735466.
# #033[4A#033[J     total [################..................................] 32.26%
# this epoch [######............................................] 12.80%
#      12600 iter, 16 epoch / 50 epochs
#     25.846 iters/sec. Estimated time to finish: 0:17:03.836297.
# #033[4A#033[J     total [################..................................] 32.51%
# this epoch [############......................................] 25.60%
#      12700 iter, 16 epoch / 50 epochs
#     25.849 iters/sec. Estimated time to finish: 0:16:59.878523.
# #033[4A#033[J     total [################..................................] 32.77%
# this epoch [###################...............................] 38.40%
#      12800 iter, 16 epoch / 50 epochs
#     25.851 iters/sec. Estimated time to finish: 0:16:55.920096.
# #033[4A#033[J     total [################..................................] 33.02%
# this epoch [#########################.........................] 51.20%
#      12900 iter, 16 epoch / 50 epochs
#     25.851 iters/sec. Estimated time to finish: 0:16:52.031817.
# #033[4A#033[J     total [################..................................] 33.28%
# this epoch [################################..................] 64.00%
#      13000 iter, 16 epoch / 50 epochs
#     25.852 iters/sec. Estimated time to finish: 0:16:48.132543.
# #033[4A#033[J     total [################..................................] 33.54%
# this epoch [######################################............] 76.80%
#      13100 iter, 16 epoch / 50 epochs
#     25.853 iters/sec. Estimated time to finish: 0:16:44.231124.
# #033[4A#033[J     total [################..................................] 33.79%
# this epoch [############################################......] 89.60%
#      13200 iter, 16 epoch / 50 epochs
#     26.027 iters/sec. Estimated time to finish: 0:16:33.681013.
# #033[4A#033[J17          0.630514    0.730436              0.798573       0.770004                  528.764
# #033[J     total [#################.................................] 34.05%
# this epoch [#.................................................]  2.40%
#      13300 iter, 17 epoch / 50 epochs
#     25.858 iters/sec. Estimated time to finish: 0:16:36.299479.
# #033[4A#033[J     total [#################.................................] 34.30%
# this epoch [#######...........................................] 15.20%
#      13400 iter, 17 epoch / 50 epochs
#     25.859 iters/sec. Estimated time to finish: 0:16:32.406995.
# #033[4A#033[J     total [#################.................................] 34.56%
# this epoch [##############....................................] 28.00%
#      13500 iter, 17 epoch / 50 epochs
#     25.858 iters/sec. Estimated time to finish: 0:16:28.563193.
# #033[4A#033[J     total [#################.................................] 34.82%
# this epoch [####################..............................] 40.80%
#      13600 iter, 17 epoch / 50 epochs
#     25.859 iters/sec. Estimated time to finish: 0:16:24.675847.
# #033[4A#033[J     total [#################.................................] 35.07%
# this epoch [##########################........................] 53.60%
#      13700 iter, 17 epoch / 50 epochs
#      25.86 iters/sec. Estimated time to finish: 0:16:20.749059.
# #033[4A#033[J     total [#################.................................] 35.33%
# this epoch [#################################.................] 66.40%
#      13800 iter, 17 epoch / 50 epochs
#     25.861 iters/sec. Estimated time to finish: 0:16:16.845155.
# #033[4A#033[J     total [#################.................................] 35.58%
# this epoch [#######################################...........] 79.20%
#      13900 iter, 17 epoch / 50 epochs
#     25.863 iters/sec. Estimated time to finish: 0:16:12.907607.
# #033[4A#033[J     total [#################.................................] 35.84%
# this epoch [##############################################....] 92.00%
#      14000 iter, 17 epoch / 50 epochs
#      26.04 iters/sec. Estimated time to finish: 0:16:02.458973.
# #033[4A#033[J18          0.625197    0.867325              0.801436       0.728603                  558.752
# #033[J     total [##################................................] 36.10%
# this epoch [##................................................]  4.80%
#      14100 iter, 18 epoch / 50 epochs
#     25.871 iters/sec. Estimated time to finish: 0:16:04.866968.
# #033[4A#033[J     total [##################................................] 36.35%
# this epoch [########..........................................] 17.60%
#      14200 iter, 18 epoch / 50 epochs
#     25.872 iters/sec. Estimated time to finish: 0:16:00.974255.
# #033[4A#033[J     total [##################................................] 36.61%
# this epoch [###############...................................] 30.40%
#      14300 iter, 18 epoch / 50 epochs
#     25.875 iters/sec. Estimated time to finish: 0:15:57.002787.
# #033[4A#033[J     total [##################................................] 36.86%
# this epoch [#####################.............................] 43.20%
#      14400 iter, 18 epoch / 50 epochs
#     25.877 iters/sec. Estimated time to finish: 0:15:53.070924.
# #033[4A#033[J     total [##################................................] 37.12%
# this epoch [###########################.......................] 56.00%
#      14500 iter, 18 epoch / 50 epochs
#     25.878 iters/sec. Estimated time to finish: 0:15:49.148176.
# #033[4A#033[J     total [##################................................] 37.38%
# this epoch [##################################................] 68.80%
#      14600 iter, 18 epoch / 50 epochs
#      25.88 iters/sec. Estimated time to finish: 0:15:45.216443.
# #033[4A#033[J     total [##################................................] 37.63%
# this epoch [########################################..........] 81.60%
#      14700 iter, 18 epoch / 50 epochs
#     26.052 iters/sec. Estimated time to finish: 0:15:35.144726.
# #033[4A#033[J     total [##################................................] 37.89%
# this epoch [###############################################...] 94.40%
#      14800 iter, 18 epoch / 50 epochs
#     26.055 iters/sec. Estimated time to finish: 0:15:31.192839.
# #033[4A#033[J19          0.616104    0.791224              0.805698       0.742138                  588.682
# #033[J     total [###################...............................] 38.14%
# this epoch [###...............................................]  7.20%
#      14900 iter, 19 epoch / 50 epochs
#     25.889 iters/sec. Estimated time to finish: 0:15:33.302647.
# #033[4A#033[J     total [###################...............................] 38.40%
# this epoch [#########.........................................] 20.00%
#      15000 iter, 19 epoch / 50 epochs
#      25.89 iters/sec. Estimated time to finish: 0:15:29.403838.
# #033[4A#033[J     total [###################...............................] 38.66%
# this epoch [################..................................] 32.80%
#      15100 iter, 19 epoch / 50 epochs
#     25.889 iters/sec. Estimated time to finish: 0:15:25.582254.
# #033[4A#033[J     total [###################...............................] 38.91%
# this epoch [######################............................] 45.60%
#      15200 iter, 19 epoch / 50 epochs
#     25.889 iters/sec. Estimated time to finish: 0:15:21.712876.
# #033[4A#033[J     total [###################...............................] 39.17%
# this epoch [#############################.....................] 58.40%
#      15300 iter, 19 epoch / 50 epochs
#      25.89 iters/sec. Estimated time to finish: 0:15:17.818271.
# #033[4A#033[J     total [###################...............................] 39.42%
# this epoch [###################################...............] 71.20%
#      15400 iter, 19 epoch / 50 epochs
#     25.887 iters/sec. Estimated time to finish: 0:15:14.073908.
# #033[4A#033[J     total [###################...............................] 39.68%
# this epoch [#########################################.........] 84.00%
#      15500 iter, 19 epoch / 50 epochs
#     26.059 iters/sec. Estimated time to finish: 0:15:04.187538.
# #033[4A#033[J     total [###################...............................] 39.94%
# this epoch [################################################..] 96.80%
#      15600 iter, 19 epoch / 50 epochs
#      26.06 iters/sec. Estimated time to finish: 0:15:00.329389.
# #033[4A#033[J20          0.60979     0.65232               0.805718       0.791799                  618.839
# #033[J     total [####################..............................] 40.19%
# this epoch [####..............................................]  9.60%
#      15700 iter, 20 epoch / 50 epochs
#      25.89 iters/sec. Estimated time to finish: 0:15:02.391105.
# #033[4A#033[J     total [####################..............................] 40.45%
# this epoch [###########.......................................] 22.40%
#      15800 iter, 20 epoch / 50 epochs
#      25.89 iters/sec. Estimated time to finish: 0:14:58.509774.
# #033[4A#033[J     total [####################..............................] 40.70%
# this epoch [#################.................................] 35.20%
#      15900 iter, 20 epoch / 50 epochs
#     25.891 iters/sec. Estimated time to finish: 0:14:54.622469.
# #033[4A#033[J     total [####################..............................] 40.96%
# this epoch [########################..........................] 48.00%
#      16000 iter, 20 epoch / 50 epochs
#     25.892 iters/sec. Estimated time to finish: 0:14:50.711837.
# #033[4A#033[J     total [####################..............................] 41.22%
# this epoch [##############################....................] 60.80%
#      16100 iter, 20 epoch / 50 epochs
#     25.892 iters/sec. Estimated time to finish: 0:14:46.860162.
# #033[4A#033[J     total [####################..............................] 41.47%
# this epoch [####################################..............] 73.60%
#      16200 iter, 20 epoch / 50 epochs
#     25.893 iters/sec. Estimated time to finish: 0:14:42.963372.
# #033[4A#033[J     total [####################..............................] 41.73%
# this epoch [###########################################.......] 86.40%
#      16300 iter, 20 epoch / 50 epochs
#     26.062 iters/sec. Estimated time to finish: 0:14:33.381564.
# #033[4A#033[J     total [####################..............................] 41.98%
# this epoch [#################################################.] 99.20%
#      16400 iter, 20 epoch / 50 epochs
#     26.062 iters/sec. Estimated time to finish: 0:14:29.571813.
# #033[4A#033[J21          0.602433    0.760326              0.809463       0.763635                  648.924
# #033[J     total [#####################.............................] 42.24%
# this epoch [######............................................] 12.00%
#      16500 iter, 21 epoch / 50 epochs
#     25.891 iters/sec. Estimated time to finish: 0:14:31.429884.
# #033[4A#033[J     total [#####################.............................] 42.50%
# this epoch [############......................................] 24.80%
#      16600 iter, 21 epoch / 50 epochs
#     25.891 iters/sec. Estimated time to finish: 0:14:27.587257.
# #033[4A#033[J     total [#####################.............................] 42.75%
# this epoch [##################................................] 37.60%
#      16700 iter, 21 epoch / 50 epochs
#      25.89 iters/sec. Estimated time to finish: 0:14:23.736743.
# #033[4A#033[J     total [#####################.............................] 43.01%
# this epoch [#########################.........................] 50.40%
#      16800 iter, 21 epoch / 50 epochs
#     25.889 iters/sec. Estimated time to finish: 0:14:19.908384.
# #033[4A#033[J     total [#####################.............................] 43.26%
# this epoch [###############################...................] 63.20%
#      16900 iter, 21 epoch / 50 epochs
#      25.89 iters/sec. Estimated time to finish: 0:14:16.040289.
# #033[4A#033[J     total [#####################.............................] 43.52%
# this epoch [######################################............] 76.00%
#      17000 iter, 21 epoch / 50 epochs
#      25.89 iters/sec. Estimated time to finish: 0:14:12.146710.
# #033[4A#033[J     total [#####################.............................] 43.78%
# ...
#      33200 iter, 42 epoch / 50 epochs
#     25.881 iters/sec. Estimated time to finish: 0:03:46.519575.
# #033[4A#033[J     total [##########################################........] 85.25%
# this epoch [###############################...................] 62.40%
#      33300 iter, 42 epoch / 50 epochs
#     25.881 iters/sec. Estimated time to finish: 0:03:42.657650.
# #033[4A#033[J     total [##########################################........] 85.50%
# this epoch [#####################################.............] 75.20%
#      33400 iter, 42 epoch / 50 epochs
#      25.88 iters/sec. Estimated time to finish: 0:03:38.801410.
# #033[4A#033[J     total [##########################################........] 85.76%
# this epoch [############################################......] 88.00%
#      33500 iter, 42 epoch / 50 epochs
#     26.049 iters/sec. Estimated time to finish: 0:03:33.538369.
# #033[4A#033[J43          0.38119     0.483298              0.879361       0.842456                  1311.38
# #033[J     total [###########################################.......] 86.02%
# this epoch [..................................................]  0.80%
#      33600 iter, 43 epoch / 50 epochs
#     25.881 iters/sec. Estimated time to finish: 0:03:31.060893.
# #033[4A#033[J     total [###########################################.......] 86.27%
# this epoch [######............................................] 13.60%
#      33700 iter, 43 epoch / 50 epochs
#     25.883 iters/sec. Estimated time to finish: 0:03:27.186123.
# #033[4A#033[J     total [###########################################.......] 86.53%
# this epoch [#############.....................................] 26.40%
#      33800 iter, 43 epoch / 50 epochs
#     25.884 iters/sec. Estimated time to finish: 0:03:23.311386.
# #033[4A#033[J     total [###########################################.......] 86.78%
# this epoch [###################...............................] 39.20%
#      33900 iter, 43 epoch / 50 epochs
#     25.882 iters/sec. Estimated time to finish: 0:03:19.464009.
# #033[4A#033[J     total [###########################################.......] 87.04%
# this epoch [##########################........................] 52.00%
#      34000 iter, 43 epoch / 50 epochs
#     25.882 iters/sec. Estimated time to finish: 0:03:15.601931.
# #033[4A#033[J     total [###########################################.......] 87.30%
# this epoch [################################..................] 64.80%
#      34100 iter, 43 epoch / 50 epochs
#     25.881 iters/sec. Estimated time to finish: 0:03:11.741205.
# #033[4A#033[J     total [###########################################.......] 87.55%
# this epoch [######################################............] 77.60%
#      34200 iter, 43 epoch / 50 epochs
#     25.881 iters/sec. Estimated time to finish: 0:03:07.880740.
# #033[4A#033[J     total [###########################################.......] 87.81%
# this epoch [#############################################.....] 90.40%
#      34300 iter, 43 epoch / 50 epochs
#     26.052 iters/sec. Estimated time to finish: 0:03:02.809118.
# #033[4A#033[J44          0.382955    0.59448               0.876821       0.8126                    1341.52
# #033[J     total [############################################......] 88.06%
# this epoch [#.................................................]  3.20%
#      34400 iter, 44 epoch / 50 epochs
#     25.879 iters/sec. Estimated time to finish: 0:03:00.167970.
# #033[4A#033[J     total [############################################......] 88.32%
# this epoch [#######...........................................] 16.00%
#      34500 iter, 44 epoch / 50 epochs
#     25.857 iters/sec. Estimated time to finish: 0:02:56.449930.
# #033[4A#033[J     total [############################################......] 88.58%
# this epoch [##############....................................] 28.80%
#      34600 iter, 44 epoch / 50 epochs
#     25.833 iters/sec. Estimated time to finish: 0:02:52.741502.
# #033[4A#033[J     total [############################################......] 88.83%
# this epoch [####################..............................] 41.60%
#      34700 iter, 44 epoch / 50 epochs
#      25.81 iters/sec. Estimated time to finish: 0:02:49.022658.
# #033[4A#033[J     total [############################################......] 89.09%
# this epoch [###########################.......................] 54.40%
#      34800 iter, 44 epoch / 50 epochs
#     25.788 iters/sec. Estimated time to finish: 0:02:45.293178.
# #033[4A#033[J     total [############################################......] 89.34%
# this epoch [#################################.................] 67.20%
#      34900 iter, 44 epoch / 50 epochs
#     25.772 iters/sec. Estimated time to finish: 0:02:41.515041.
# #033[4A#033[J     total [############################################......] 89.60%
# this epoch [#######################################...........] 80.00%
#      35000 iter, 44 epoch / 50 epochs
#     25.919 iters/sec. Estimated time to finish: 0:02:36.735417.
# #033[4A#033[J     total [############################################......] 89.86%
# this epoch [##############################################....] 92.80%
#      35100 iter, 44 epoch / 50 epochs
#       25.9 iters/sec. Estimated time to finish: 0:02:32.995211.
# #033[4A#033[J45          0.374371    0.555495              0.881314       0.82076                   1373.85
# #033[J     total [#############################################.....] 90.11%
# this epoch [##................................................]  5.60%
#      35200 iter, 45 epoch / 50 epochs
#     25.732 iters/sec. Estimated time to finish: 0:02:30.103180.
# #033[4A#033[J     total [#############################################.....] 90.37%
# this epoch [#########.........................................] 18.40%
#      35300 iter, 45 epoch / 50 epochs
#     25.733 iters/sec. Estimated time to finish: 0:02:26.214517.
# #033[4A#033[J     total [#############################################.....] 90.62%
# this epoch [###############...................................] 31.20%
#      35400 iter, 45 epoch / 50 epochs
#     25.731 iters/sec. Estimated time to finish: 0:02:22.335509.
# #033[4A#033[J     total [#############################################.....] 90.88%
# this epoch [#####################.............................] 44.00%
#      35500 iter, 45 epoch / 50 epochs
#      25.73 iters/sec. Estimated time to finish: 0:02:18.459046.
# #033[4A#033[J     total [#############################################.....] 91.14%
# this epoch [############################......................] 56.80%
#      35600 iter, 45 epoch / 50 epochs
#     25.731 iters/sec. Estimated time to finish: 0:02:14.565287.
# #033[4A#033[J     total [#############################################.....] 91.39%
# this epoch [##################################................] 69.60%
#      35700 iter, 45 epoch / 50 epochs
#     25.731 iters/sec. Estimated time to finish: 0:02:10.679013.
# #033[4A#033[J     total [#############################################.....] 91.65%
# this epoch [#########################################.........] 82.40%
#      35800 iter, 45 epoch / 50 epochs
#     25.901 iters/sec. Estimated time to finish: 0:02:05.960043.
# #033[4A#033[J     total [#############################################.....] 91.90%
# this epoch [###############################################...] 95.20%
#      35900 iter, 45 epoch / 50 epochs
#     25.901 iters/sec. Estimated time to finish: 0:02:02.100189.
# #033[4A#033[J46          0.382891    0.511236              0.877521       0.838077                  1403.93
# #033[J     total [##############################################....] 92.16%
# this epoch [###...............................................]  8.00%
#      36000 iter, 46 epoch / 50 epochs
#      25.73 iters/sec. Estimated time to finish: 0:01:59.022893.
# #033[4A#033[J     total [##############################################....] 92.42%
# this epoch [##########........................................] 20.80%
#      36100 iter, 46 epoch / 50 epochs
#     25.724 iters/sec. Estimated time to finish: 0:01:55.163095.
# #033[4A#033[J     total [##############################################....] 92.67%
# this epoch [################..................................] 33.60%
#      36200 iter, 46 epoch / 50 epochs
#     25.716 iters/sec. Estimated time to finish: 0:01:51.310336.
# #033[4A#033[J     total [##############################################....] 92.93%
# this epoch [#######################...........................] 46.40%
#      36300 iter, 46 epoch / 50 epochs
#     25.713 iters/sec. Estimated time to finish: 0:01:47.436193.
# #033[4A#033[J     total [##############################################....] 93.18%
# this epoch [#############################.....................] 59.20%
#      36400 iter, 46 epoch / 50 epochs
#     25.702 iters/sec. Estimated time to finish: 0:01:43.591453.
# #033[4A#033[J     total [##############################################....] 93.44%
# this epoch [###################################...............] 72.00%
#      36500 iter, 46 epoch / 50 epochs
#     25.701 iters/sec. Estimated time to finish: 0:01:39.702754.
# #033[4A#033[J     total [##############################################....] 93.70%
# this epoch [##########################################........] 84.80%
#      36600 iter, 46 epoch / 50 epochs
#      25.87 iters/sec. Estimated time to finish: 0:01:35.188795.
# #033[4A#033[J     total [##############################################....] 93.95%
# this epoch [################################################..] 97.60%
#      36700 iter, 46 epoch / 50 epochs
#     25.869 iters/sec. Estimated time to finish: 0:01:31.324456.
# #033[4A#033[J47          0.373927    0.486413              0.880682       0.838873                  1434.43
# #033[J     total [###############################################...] 94.21%
# this epoch [#####.............................................] 10.40%
#      36800 iter, 47 epoch / 50 epochs
#     25.701 iters/sec. Estimated time to finish: 0:01:28.032018.
# #033[4A#033[J     total [###############################################...] 94.46%
# this epoch [###########.......................................] 23.20%
#      36900 iter, 47 epoch / 50 epochs
#       25.7 iters/sec. Estimated time to finish: 0:01:24.144234.
# #033[4A#033[J     total [###############################################...] 94.72%
# this epoch [#################.................................] 36.00%
#      37000 iter, 47 epoch / 50 epochs
#     25.701 iters/sec. Estimated time to finish: 0:01:20.248845.
# #033[4A#033[J     total [###############################################...] 94.98%
# this epoch [########################..........................] 48.80%
#      37100 iter, 47 epoch / 50 epochs
#     25.701 iters/sec. Estimated time to finish: 0:01:16.359183.
# #033[4A#033[J     total [###############################################...] 95.23%
# this epoch [##############################....................] 61.60%
#      37200 iter, 47 epoch / 50 epochs
#     25.702 iters/sec. Estimated time to finish: 0:01:12.465717.
# #033[4A#033[J     total [###############################################...] 95.49%
# this epoch [#####################################.............] 74.40%
#      37300 iter, 47 epoch / 50 epochs
#     25.704 iters/sec. Estimated time to finish: 0:01:08.569517.
# #033[4A#033[J     total [###############################################...] 95.74%
# this epoch [###########################################.......] 87.20%
#      37400 iter, 47 epoch / 50 epochs
#     25.874 iters/sec. Estimated time to finish: 0:01:04.252456.
# #033[4A#033[J48          0.368311    0.448187              0.882823       0.858181                  1464.46
# #033[J     total [################################################..] 96.00%
# this epoch [..................................................]  0.00%
#      37500 iter, 48 epoch / 50 epochs
#     25.713 iters/sec. Estimated time to finish: 0:01:00.767432.
# #033[4A#033[J     total [################################################..] 96.26%
# this epoch [######............................................] 12.80%
#      37600 iter, 48 epoch / 50 epochs
#     25.714 iters/sec. Estimated time to finish: 0:00:56.874857.
# #033[4A#033[J     total [################################################..] 96.51%
# this epoch [############......................................] 25.60%
#      37700 iter, 48 epoch / 50 epochs
#     25.712 iters/sec. Estimated time to finish: 0:00:52.990169.
# #033[4A#033[J     total [################################################..] 96.77%
# this epoch [###################...............................] 38.40%
#      37800 iter, 48 epoch / 50 epochs
#     25.715 iters/sec. Estimated time to finish: 0:00:49.096743.
# #033[4A#033[J     total [################################################..] 97.02%
# this epoch [#########################.........................] 51.20%
#      37900 iter, 48 epoch / 50 epochs
#     25.716 iters/sec. Estimated time to finish: 0:00:45.206018.
# #033[4A#033[J     total [################################################..] 97.28%
# this epoch [################################..................] 64.00%
#      38000 iter, 48 epoch / 50 epochs
#     25.718 iters/sec. Estimated time to finish: 0:00:41.313197.
# #033[4A#033[J     total [################################################..] 97.54%
# this epoch [######################################............] 76.80%
#      38100 iter, 48 epoch / 50 epochs
#      25.72 iters/sec. Estimated time to finish: 0:00:37.422286.
# #033[4A#033[J     total [################################################..] 97.79%
# this epoch [############################################......] 89.60%
#      38200 iter, 48 epoch / 50 epochs
#      25.89 iters/sec. Estimated time to finish: 0:00:33.313898.
# #033[4A#033[J49          0.377428    0.471442              0.880595       0.846935                  1494.49
# #033[J     total [#################################################.] 98.05%
# this epoch [#.................................................]  2.40%
#      38300 iter, 49 epoch / 50 epochs
#     25.721 iters/sec. Estimated time to finish: 0:00:29.644551.
# #033[4A#033[J     total [#################################################.] 98.30%
# this epoch [#######...........................................] 15.20%
#      38400 iter, 49 epoch / 50 epochs
#     25.722 iters/sec. Estimated time to finish: 0:00:25.755819.
# #033[4A#033[J     total [#################################################.] 98.56%
# this epoch [##############....................................] 28.00%
#      38500 iter, 49 epoch / 50 epochs
#     25.725 iters/sec. Estimated time to finish: 0:00:21.865473.
# #033[4A#033[J     total [#################################################.] 98.82%
# this epoch [####################..............................] 40.80%
#      38600 iter, 49 epoch / 50 epochs
#     25.725 iters/sec. Estimated time to finish: 0:00:17.978833.
# #033[4A#033[J     total [#################################################.] 99.07%
# this epoch [##########################........................] 53.60%
#      38700 iter, 49 epoch / 50 epochs
#     25.726 iters/sec. Estimated time to finish: 0:00:14.091043.
# #033[4A#033[J     total [#################################################.] 99.33%
# this epoch [#################################.................] 66.40%
#      38800 iter, 49 epoch / 50 epochs
#     25.725 iters/sec. Estimated time to finish: 0:00:10.203935.
# #033[4A#033[J     total [#################################################.] 99.58%
# this epoch [#######################################...........] 79.20%
#      38900 iter, 49 epoch / 50 epochs
#     25.723 iters/sec. Estimated time to finish: 0:00:06.317345.
# #033[4A#033[J     total [#################################################.] 99.84%
# this epoch [##############################################....] 92.00%
#      39000 iter, 49 epoch / 50 epochs
#     25.895 iters/sec. Estimated time to finish: 0:00:02.413601.
# #033[4A#033[J50          0.367747    0.471307              0.881662       0.848029                  1524.67
# #033[J
# ===== Job Complete =====
# Billable seconds: 1677

# %% [markdown]
# Our Chainer script writes various artifacts, such as plots, to a directory `output_data_dir`, the contents of which which SageMaker uploads to S3. Now we download and extract these artifacts.

# %%
from s3_util import retrieve_output_from_s3

chainer_training_job = chainer_estimator.latest_training_job.name

desc = sagemaker_session.sagemaker_client.describe_training_job(TrainingJobName=chainer_training_job)
output_data = desc['ModelArtifacts']['S3ModelArtifacts'].replace('model.tar.gz', 'output.tar.gz')

retrieve_output_from_s3(output_data, 'output/single_machine_cifar')

# %%
# Executing as code to reload images so that browsers don't render cached images.
from IPython.display import Markdown
import time
_nonce = time.time()

Markdown("""
These plots show the accuracy and loss over epochs:

<img style="display: inline;" src="output/single_machine_cifar/accuracy.png?{0}" />
<img style="display: inline;" src="output/single_machine_cifar/loss.png?{0}" />""".format(_nonce))
# Out:
# These plots show the accuracy and loss over epochs:
#
# <img style="display: inline;" src="output/single_machine_cifar/accuracy.png?1525466159.2398272" />
# <img style="display: inline;" src="output/single_machine_cifar/loss.png?1525466159.2398272" />

# %% [markdown]
# ## Deploying the Trained Model
#
# After training, we use the Chainer estimator object to create and deploy a hosted prediction endpoint. We can use a CPU-based instance for inference (in this case an `ml.m4.xlarge`), even though we trained on GPU instances.
#
# The predictor object returned by `deploy` lets us call the new endpoint and perform inference on our sample images.

# %%
predictor = chainer_estimator.deploy(initial_instance_count=1, instance_type='ml.m4.xlarge')
# Out:
# INFO:sagemaker:Creating model with name: sagemaker-chainer-2018-05-04-20-05-57-636
# INFO:sagemaker:Creating endpoint with name sagemaker-chainer-2018-05-04-20-05-57-636
# ------------------------------------------------------------!

# %% [markdown]
# ### CIFAR10 sample images
#
# We'll use these CIFAR10 sample images to test the service:
#
# <img style="display: inline; height: 32px; margin: 0.25em" src="images/airplane1.png" />
# <img style="display: inline; height: 32px; margin: 0.25em" src="images/automobile1.png" />
# <img style="display: inline; height: 32px; margin: 0.25em" src="images/bird1.png" />
# <img style="display: inline; height: 32px; margin: 0.25em" src="images/cat1.png" />
# <img style="display: inline; height: 32px; margin: 0.25em" src="images/deer1.png" />
# <img style="display: inline; height: 32px; margin: 0.25em" src="images/dog1.png" />
# <img style="display: inline; height: 32px; margin: 0.25em" src="images/frog1.png" />
# <img style="display: inline; height: 32px; margin: 0.25em" src="images/horse1.png" />
# <img style="display: inline; height: 32px; margin: 0.25em" src="images/ship1.png" />
# <img style="display: inline; height: 32px; margin: 0.25em" src="images/truck1.png" />

# %% [markdown]
# ## Predicting using SageMaker Endpoint
#
# We batch the images together into a single NumPy array to obtain multiple inferences with a single prediction request.

# %%
from skimage import io
import numpy as np

def read_image(filename):
    img = io.imread(filename)
    img = np.array(img).transpose(2, 0, 1)
    img = np.expand_dims(img, axis=0)
    img = img.astype(np.float32)
    img *= 1. / 255.
    img = img.reshape(3, 32, 32)
    return img


def read_images(filenames):
    return np.array([read_image(f) for f in filenames])

filenames = ['images/airplane1.png',
             'images/automobile1.png',
             'images/bird1.png',
             'images/cat1.png',
             'images/deer1.png',
             'images/dog1.png',
             'images/frog1.png',
             'images/horse1.png',
             'images/ship1.png',
             'images/truck1.png']

image_data = read_images(filenames)

# %% [markdown]
# The predictor runs inference on our input data and returns a list of predictions whose argmax gives the predicted label of the input data.

# %%
response = predictor.predict(image_data)

for i, prediction in enumerate(response):
    print('image {}: prediction: {}'.format(i, prediction.argmax(axis=0)))
# Out:
# image 0: prediction: 0
# image 1: prediction: 1
# image 2: prediction: 2
# image 3: prediction: 3
# image 4: prediction: 4
# image 5: prediction: 5
# image 6: prediction: 6
# image 7: prediction: 7
# image 8: prediction: 8
# image 9: prediction: 9

# %% [markdown]
# ## Cleanup
#
# After you have finished with this example, remember to delete the prediction endpoint to release the instance(s) associated with it.

# %%
sagemaker.Session().delete_endpoint(predictor.endpoint)
# Out:
# INFO:sagemaker:Deleting endpoint with name: sagemaker-chainer-2018-05-04-20-05-57-636
